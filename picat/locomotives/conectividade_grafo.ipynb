# %%
# %load_ext ipicat
# Out:
# The ipicat extension is already loaded. To reload it, use:
#   %reload_ext ipicat

# %%
# %%picat
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# import util.
# import ordset.
# %import sys.
# import a_graph_11_nodes.
# %load("a_graph_11_nodes.pi").
#
# main ?=>
#
#     Graph = findall((X,Y,Z) , arc(X,Y,Z)),
#     printf("\n Oriented Graph %w", Graph),
#     L_Nodes = all_nodes(), %%%% to be used in the future
#
#     Init_Node= min(L_Nodes),
#
#     Set_Edges = new_ordset(all_edges()),
#     printf("\n Start: %w", Init_Node),
#     printf("\n All Nodes: %w", L_Nodes),
#     printf("\n All Edges: %w\n", Set_Edges),
#
#     %printf("\n Start: %w\t  End: %w\n All_Nodes: %w",Init_Node, End_Node, L_Nodes),
#     delete(L_Nodes, Init_Node) = Rest,
#
#     All_Edges =[],
#     foreach(End_Node in Rest)
#         printf("\n Start: %w\t  End: %w", Init_Node, End_Node),
#     if ( dfs_connected(Init_Node, End_Node, [Init_Node], [], Sol) ) then
#             printf("\n Path: %w",   reverse(Sol[1])),
#             printf("\t Edges: %w\n", reverse(Sol[2])),
#             All_Edges := All_Edges++Sol[2]
#         else
#             printf("\n ==> NO reachable from: %w to: %w\n", Init_Node, End_Node)
#     end
#     end,
#     Edges_Not_Repeated = remove_dups(All_Edges),
#     Set_Edges_Visited = new_ordset(Edges_Not_Repeated),
#     printf("\n All Edges Visited: %w ", Set_Edges_Visited ),
#     %subtract(OSet1,OSet2)=OSet3: This function returns an ordered set that contains all of the elements of OSet1 which are not in OSet2.
#     Not_Visited = subtract(Set_Edges, Set_Edges_Visited),
#     printf("\n NOT Visited Edges: %w ", Not_Visited ),
#
#     %%% ARRAY usefull
#     %%%% ESTUDO AQUI ....
#
#     printf("\n\n PAUSA AQUI: UM ESTUDO "),
#     Estudo = findall(Sol,  (dfs_connected('02', '72', ['02'], [], Sol))  ),
#     Temp1 = get_second_elements(Estudo),
#     printf("\n Numero de Caminhos de  '02' -> '72': %w ", len(Temp1)),
#     printf("\n Caminhos Alternativos de  '02' -> '72': %w ", Temp1),
#     Temp2 =  remove_dups(flatten(Temp1)),
#     printf("\n Estudo de  '02' até '72': %w ", Temp2),
#
#     printf("\n End of main: OK\n").
#     %%%%
#     %spy($dfs_connected/5),
#     %nospy,
#
# main => printf("\n End of main with fail ... NO SOLUTION").
#
# all_nodes() = Set =>
#         L1 = findall(X, arc(X,Y,_)),
#         L2 = findall(Y, arc(X,Y,_)),
#         new_ordset(L1) = Set_1,
#         new_ordset(L2) = Set_2,
#         Set = union(Set_1, Set_2).
#
# all_edges() = Set =>
#     L = findall(X, arc(_,_,X)),
#     new_ordset(L) = Set.  %%% remove duplicates ...
#
#
# get_second_elements(L) = Result =>
#     Result = [Array[2] : Array in L].
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# % KERNEL DFS
# dfs_connected(Node, End_Node, L_Nodes_Visited, L_Edges, Sol) ?=>
#     Node == End_Node,
#     N = len(L_Edges),
#     N>0,
#     %%%printf("\n Theres is a path!").
#     Sol = {L_Nodes_Visited, L_Edges}.
#
# /*
# dfs_connected(Node, End_Node, L_Nodes_Visited, L_Edges, Sol) ?=>
#     Node == End_Node,
#     N = len(L_Edges),
#     N==0,
#     Sol = 'NO'.
# */
#
#
#
# dfs_connected(Node, End_Node, Partial_Path, Partial_Edges, Sol) =>
#
#    arc(Node, Next, Edge),
#    not member(Next, Partial_Path),
#    append([Next], Partial_Path,  L_Nodes_Visited),
#    append([Edge], Partial_Edges, L_Edges),
#    dfs_connected(Next, End_Node, L_Nodes_Visited, L_Edges, Sol).
#
#  /*
# dfs_connected(_, _, _, _, Sol) =>
#     Sol='NO'.
# */
# %   {[],[]},!.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# /*
# HAKAN
# Graph(Graph) =>
#   Graph =
#        [[1, 2],
#         ...
#        [4, 8]].
#
# data(edge,Graph,D) =>
#   Graph = {{1,2},
#            {1,3},
#            {1,4},
#            {2,3},
#            {2,4},
#            {3,4}},
#   D = [3,2,1,0].
#
# connect(a, [b, j, k]).
# connect(b, [a, c, p]).
# connect(c, [b, d, l]).
# */
# Out:
#  Oriented Graph [(02,22,none),(12,22,none),(22,31,a001),(22,72,none),(31,41,none),(41,52,a002),(41,61,none),(52,72,none),(61,71,none),(61,72,a003),(71,80,#bno),(72,80,#dro),(111,222,fake_arc)]
#  Start: 02
#  All Nodes: [02,111,12,22,222,31,41,52,61,71,72,80]
#  All Edges: [#bno,#dro,a001,a002,a003,fake_arc,none]
#
#  Start: 02	  End: 111
#  ==> NO reachable from: 02 to: 111
#
#  Start: 02	  End: 12
#  ==> NO reachable from: 02 to: 12
#
#  Start: 02	  End: 22
#  Path: [02,22]	 Edges: [none]
#
#  Start: 02	  End: 222
#  ==> NO reachable from: 02 to: 222
#
#  Start: 02	  End: 31
#  Path: [02,22,31]	 Edges: [none,a001]
#
#  Start: 02	  End: 41
#  Path: [02,22,31,41]	 Edges: [none,a001,none]
#
#  Start: 02	  End: 52
#  Path: [02,22,31,41,52]	 Edges: [none,a001,none,a002]
#
#  Start: 02	  End: 61
#  Path: [02,22,31,41,61]	 Edges: [none,a001,none,none]
#
#  Start: 02	  End: 71
#  Path: [02,22,31,41,61,71]	 Edges: [none,a001,none,none,none]
#
#  Start: 02	  End: 72
#  Path: [02,22,31,41,52,72]	 Edges: [none,a001,none,a002,none]
#
#  Start: 02	  End: 80
#  Path: [02,22,31,41,52,72,80]	 Edges: [none,a001,none,a002,none,#dro]
#
#  All Edges Visited: [#dro,a001,a002,none]
#  NOT Visited Edges: [#bno,a003,fake_arc]
#
#  PAUSA AQUI: UM ESTUDO
#  Numero de Caminhos de  '02' -> '72': 3
#  Caminhos Alternativos de  '02' -> '72': [[none,a002,none,a001,none],[a003,none,none,a001,none],[none,none]]
#  Estudo de  '02' até '72': [none,a002,a001,a003]
#  End of main: OK

# %%
# %%picat
# import ordset.
#
# main ?=>
# L = [(12,22,none),(22,31,a001), (12,22,none),(22,31,a001),(22,72,none),(31,41,none),(41,52,a002),(41,61,none),(52,72,none),(61,71,none),(61,72,a003),(71,80,'#bno'),(72,80,'#dro')],
#     printf("\n Lst: %w", L),
#     new_ordset(L) = S,
#     printf("\n Set: %w", S).
# main => printf("\n With Fail").
# Out:
#  Lst: [(12,22,none),(22,31,a001),(12,22,none),(22,31,a001),(22,72,none),(31,41,none),(41,52,a002),(41,61,none),(52,72,none),(61,71,none),(61,72,a003),(71,80,#bno),(72,80,#dro)]
#  Set: [(12,22,none),(22,31,a001),(22,72,none),(31,41,none),(41,52,a002),(41,61,none),(52,72,none),(61,71,none),(61,72,a003),(71,80,#bno),(72,80,#dro)]

# %%
# %%picat
#
# main => Graph =
#         [('02', '22', 'none'), ('12', '22', 'none'),
#         ('22', '31', 'a001'), ('22', '72', 'none'), ('31', '41', 'none'),
#         ('41', '52', 'a002'), ('41', '61', 'none'), ('52', '72', 'none'),
#         ('61', '71', 'none'), ('61', '72', 'a003'),
#         ('71', '80', '#bno'), ('72', '80', '#dro'), ('111', '222', 'fake_arc') ],
#         printf("\n NOS %w", get_nodes(Graph) ),
#         printf("\n ARESTAS %w", get_edges(Graph) )
#         .
#
# get_edges(L) = Edges =>
#         Edges = sort_remove_dups( {N : T in L, (N1, N2, N) = T } ) .
#
# get_nodes(L) = Nodes =>
#         Nodes = sort_remove_dups( {N : T in L, (N1, N2, _) = T, N in [N1, N2]} ) .
# Out:
#  NOS {02,111,12,22,222,31,41,52,61,71,72,80}
#  ARESTAS {#bno,#dro,a001,a002,a003,fake_arc,none}
